# %% [markdown]
# # <u>BERTuality</u>
#
#  <p style='text-align: justify;'>In this repository, we explore a way to check the topicality of textual data using the "BERT" language model and generate data corresponding to topicality. Our concept is called BERT-actuality (=BERTuality) and is a pipeline that is able to overcome the limitations of a pre-trained large language model by collecting correct data according to its topicality and predicting a correct value for a searched value.
# <br><br>
# <b>Why is this important?</b> There are over 6.6 million English-language Wikipedia articles on the Internet. In the USA alone, over 5,000 new news articles are published every day. Assuming that not every source is constantly updated, it can be stated that a large amount of outdated information exists. In this context, timeliness is the property of information to be relevant to the present. Outdated information no longer corresponds to the current conditions of the real world because it has become obsolete due to decay over time. Thus, outdated information poses a danger because it is misinformation in our case. The use of misinformation can lead to misunderstanding, economic or reputational damage. Therefore, it is of great interest to both individuals and businesses to obtain and use only current information. We describe a best practice for how BERT keeps information current.
# <br><br>
# <b>How do we achieve it?</b> BERTuality generates a current value for the [MASK] token for a sentence of the form "Prime Minister [MASK] is the leader of Japan". In this case, the result is the word "Kishida" (as of February 2023). To predict the word for the [MASK] token, the language model BERT, which was previously sensitized to the current state, is used. In the first step, BERTuality analyzes the outdated information and systematically extracts up-to-date information from various data sources. In the second step, this information is split into individual sentences and transformed into an optimal form for BERT. Procedures are presented that allow BERT to be made aware of timeliness using these sentences. In the third step, BERT is used to generate a correct and up-to-date prediction.</p>

# %% [markdown]
# # 1. <u>Dependencies</u>
#
# <p style='text-align: justify;'>To keep this notebook readable and simple, we will keep most of the code out of this notebook and import all the necessary functions as we go along in the chapters we need. If you need more information about the implementation, you will have to refer to files in the bertuality package imported here. But for now, we'll import all the necessary dependencies:</p>

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import BertTokenizer, BertForMaskedLM, pipeline
from bertuality import BERTuality
from bertuality import BERTuality_loader
from bertuality import BERTuality_quickstart

import pandas as pd
pd.set_option('display.max_colwidth', None)
import os

# %% [markdown]
# <p style='text-align: justify;'>Additionally, we need to define a path to our BERTuality package and need to import our pre-saved and pre-trained model. This pre-trained model is equal to "bert-based-uncased". While it is also possible to easily import models via the Hugginface API, we also saved it into the package files. </p>

# %%
path = os.path.join(os.getcwd(), "bertuality")

# %%
model = BertForMaskedLM.from_pretrained(os.path.join(path, "model"))
tokenizer = BertTokenizer.from_pretrained(os.path.join(path, "tokenizer"))

# %% [markdown]
# # 2. <u>The Basics needed</u>
#
# <p style='text-align: justify;'>The training data of BERT includes books with 800 million words and Wikipedia articles with 2.5 billion English words. In the original research work, the BERT core model is trained with two self-supervised learning tasks, including the Masked Language Model. In this pre-training method, some tokens are masked by [MASK] tokens. The model is then trained to predict the masked tokens by determining the context from the surrounding tokens.
# To predict the [MASK] tokens, we use a pipeline from the Transformers library. Our goal is to use BERT to make both contextually correct and topical statements about a previously masked [MASK] token.</p>
#
#
# ## 2.1 <u>Problems with pre-trained models</u>
#
# <p style='text-align: justify;'>To have a deeper look at the predictions of a pretrained model we have to define a pipeline first. This can be easily done with the huggingface models and api's. The pipeline below can be used for so called masekd predictions, where the [MASK] Token will be predicted by the model.</p>

# %%
pre_trained_pipeline = pipeline("fill-mask", model=model, tokenizer=tokenizer)

# %% [markdown]
# <p style='text-align: justify;'>Below are the predictions for two [MASK] sentences, each containing a [MASK] token.</p>

# %%
test_sentence_1 = "Paris is the capital of [MASK]."

prediction_1 = pre_trained_pipeline(test_sentence_1)

prediction_1_df = pd.DataFrame(prediction_1)
prediction_1_df[:1].style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'center')]) ])
# Out:
# <style type="text/css">
# #T_2766d th {
#   text-align: center;
# }
# #T_2766d_row0_col0, #T_2766d_row0_col1, #T_2766d_row0_col2, #T_2766d_row0_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_2766d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2766d_level0_col0" class="col_heading level0 col0" >sequence</th>
#       <th id="T_2766d_level0_col1" class="col_heading level0 col1" >score</th>
#       <th id="T_2766d_level0_col2" class="col_heading level0 col2" >token</th>
#       <th id="T_2766d_level0_col3" class="col_heading level0 col3" >token_str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2766d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2766d_row0_col0" class="data row0 col0" >paris is the capital of france.</td>
#       <td id="T_2766d_row0_col1" class="data row0 col1" >0.950923</td>
#       <td id="T_2766d_row0_col2" class="data row0 col2" >2605</td>
#       <td id="T_2766d_row0_col3" class="data row0 col3" >f r a n c e</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p style='text-align: justify;'>The prediction for the first sentence is correct. Since this information is not related to actuality, it does not change over time. So we can say that the BERT "knows" this information based on its training data and predicts correctly.</p>

# %%
test_sentence_2 = "Tim Cook is the CEO of [MASK]."

prediction_2 = pre_trained_pipeline(test_sentence_2)

prediction_2_df = pd.DataFrame(prediction_2)
prediction_2_df[:1].style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'center')]) ])
# Out:
# <style type="text/css">
# #T_01c6f th {
#   text-align: center;
# }
# #T_01c6f_row0_col0, #T_01c6f_row0_col1, #T_01c6f_row0_col2, #T_01c6f_row0_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_01c6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01c6f_level0_col0" class="col_heading level0 col0" >sequence</th>
#       <th id="T_01c6f_level0_col1" class="col_heading level0 col1" >score</th>
#       <th id="T_01c6f_level0_col2" class="col_heading level0 col2" >token</th>
#       <th id="T_01c6f_level0_col3" class="col_heading level0 col3" >token_str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01c6f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01c6f_row0_col0" class="data row0 col0" >tim cook is the ceo of amazon.</td>
#       <td id="T_01c6f_row0_col1" class="data row0 col1" >0.007595</td>
#       <td id="T_01c6f_row0_col2" class="data row0 col2" >9733</td>
#       <td id="T_01c6f_row0_col3" class="data row0 col3" >a m a z o n</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p style='text-align: justify;'>However, this is not always the case. If a piece of information relates to time, it may become obsolete due to the lapse of time. For example, the data used to train BERT may become obsolete after training. Consequently, BERT then has an outdated knowledge state and cannot make the current prediction.
# <br><br>
# In order to get a correct prediction also for update related information, BERT needs to be made aware of updates. To this end, we will look at a way to accomplish this.</p>

# %% [markdown]
# ## 2.2 <u>Approaches to create a sensitivity to the topicallity</u>
#
# <p style='text-align: justify;'>There are several approaches to making BERT aware of a current context. Essentially, it involves "teaching" BERT new content that is unknown due to the time and topic constraints of the training data. In our case of thematic awareness, BERT is taught the current state of the current information.
# <br><br>
# One of these approaches is called Priming and is the idea that exposure to one stimulus may influence a response to a subsequent stimulus, without conscious guidance or intention. The priming effect refers to the positive or negative effect of a rapidly presented stimulus (priming stimulus) on the processing of a second stimulus (target stimulus) that appears shortly after.
# <br><br>
# Priming can also be used with BERT to influence the prediction of a [MASK] token. To do this, the word or phrase that is to be used to influence BERT is concatenated with the [MASK] phrase. In the case of topicality sensitization, the priming may look like the following:</p>

# %%
add_information = "He has been the chief executive officer of Apple Inc. since 2011."

primed_sentence =  test_sentence_2 + " " + add_information

primed_prediction = pre_trained_pipeline(primed_sentence)

primed_prediction_df = pd.DataFrame(primed_prediction)
primed_prediction_df[:1].style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'center')]) ])
# Out:
# <style type="text/css">
# #T_8a127 th {
#   text-align: center;
# }
# #T_8a127_row0_col0, #T_8a127_row0_col1, #T_8a127_row0_col2, #T_8a127_row0_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_8a127">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a127_level0_col0" class="col_heading level0 col0" >sequence</th>
#       <th id="T_8a127_level0_col1" class="col_heading level0 col1" >score</th>
#       <th id="T_8a127_level0_col2" class="col_heading level0 col2" >token</th>
#       <th id="T_8a127_level0_col3" class="col_heading level0 col3" >token_str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a127_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a127_row0_col0" class="data row0 col0" >tim cook is the ceo of apple. he has been the chief executive officer of apple inc. since 2011.</td>
#       <td id="T_8a127_row0_col1" class="data row0 col1" >0.941625</td>
#       <td id="T_8a127_row0_col2" class="data row0 col2" >6207</td>
#       <td id="T_8a127_row0_col3" class="data row0 col3" >a p p l e</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p style='text-align: justify;'>It is shown that concatenating additional information (=input sentences) with the [MASK] sentence affects the prediction of the [MASK] token. Without priming, BERT predicted that Tim Cook is the CEO of Amazon. With priming, Apple is predicted. This principle of priming can also influence the prediction of BERT just by the presence of individual words before or after the [MASK] sentence.
#
# It follows that the knowledge of the BERT can be influenced by adding more information. In the following, we will use this principle for our BERTuality pipeline, which will be able to predict current information without having a current knowledge base.</p>

# %% [markdown]
# # 3. <u>BERTuality</u>
#
# <p style='text-align: justify;'>In this chapter, we will go over the BERTuality pipeline and introduce its structure and the functionality of the individual modules. This is followed by a schematic overview of the process:</p>
#
#
# TODO - Import image of pipeline
#
# <p style='text-align: justify;'><b>Description:</b> First, the masked sentence is passed to the pipeline to extract all relevant keywords from it. Based on the keywords, relevant data is searched in an arbitrary data source. Then, the found input data passes through the text data preparation and query module to filter out optimal input sentences. Based on these prepared input sentences, a suitable and up-to-date token for the [MASK] token is predicted for the masked sentence.</p>

# %% [markdown]
# ## 3.1 <u>Keyword Extraction</u>
#
# <p style='text-align: justify;'>First, the keywords are extracted from the [MASK] sentence, which will be used in the next steps to search for the relevant information. For an optimal search it is of interest that the list of keywords contains only the most relevant words.
# <br><br>
# To obtain an optimal keyword extraction, the part-of-speech method is used for this purpose. POS tagging is the assignment of a POS tag to each word according to its definition and context. The various POS tags correspond to Penn Treebank's tag set, which includes various tags for word types such as verbs, adjectives, and nouns.</p>

# %%
# a simple test sentence for exploring the bertuality pipeline

mask_sentence = "Prime minister [MASK] is the leader of Japan."

# %%
keywords = BERTuality.pos_keywords(mask_sentence)

print('The keywords of "{}" are {}'.format(mask_sentence, keywords))
# Out:
# The keywords of "Prime minister [MASK] is the leader of Japan." are ['Prime', 'minister', 'Japan']

# %% [markdown]
# <p style='text-align: justify;'>Another possibility to extract relevant keywords from the masked sentence would be Named Entity Recognition, but this will not be discussed further here. Due to the very good results for us, the POS method for BERTuality is used in the following.</p>

# %% [markdown]
# ## 3.2 <u>Loading the data</u>
#
# <p style='text-align: justify;'>As mentioned before, the basic idea of BERTuality is that BERT is primed using temporally current input data to make a correct prediction for the [MASK] token. Thus, the quality of a prediction depends in particular on the data quality of a source. The reason for this is the later extraction of optimal sentences from the data source, which are used as input for BERT. At the moment, the BERTuality pipeline uses three freely available data sources from the Internet.</p>
#
# These are APIs for:
#     <ul>
#         <li><b>NewsAPI</b>, which primarily provides short descriptions of articles from over 80,000 sources, mostly one to two sentences in length.</li>
#         <li><b>TheGuardian</b>, which offers detailed and longer journalistic articles with many sentences on current topics.</li>
#         <li><b>Wikipedia</b>, which serves as a backup in case no current news articles can be found on a particular topic</li>
#     </ul>
#
# <p style='text-align: justify;'>The keywords generated by POS tagging are concatenated into a single string using AND operators in this step. The created string is passed as a search query to a function that coordinates the search across the different APIs. Afterwards, the text data is extracted from all search results of the found sources with the help of web scrapers. The quality of the selected keywords is important here, as suitable sources are searched exclusively on the basis of them. In this step, special care must be taken to ensure that only current data from a specific time period is obtained.</p>

# %%
# Api's can be called individually with their own function, but for simplicity we will call the general news_loader function:

textual_data = BERTuality_loader.news_loader(from_date="2023-02-01", 
                                             to_date="2023-03-01", 
                                             keywords=keywords, 
                                             use_NewsAPI=True, 
                                             use_guardian=True, 
                                             use_wikipedia=True)

# %%
news_api = textual_data[0]

print(f"Found {len(news_api)} articles for NewsApi:")
      
show_articles = 3   
for i in range(show_articles):
    print(f"\nArticle Nr. {i}:")
    print(news_api[i])
# Out:
# Found 100 articles for NewsApi:
#
# Article Nr. 0:
# JAXA second attempt at launching the H3 rocket has ended up becoming a major setback for Japan space ambitions. While the rocket was able to leave the launch pad the country space authorities were forced to activate its flight termination system a few.
#
# Article Nr. 1:
# BBC correspondents explain why historic rivals are trying to rebuild trust and who stands to gain.
#
# Article Nr. 2:
# The number of births registered in Japan plummeted to another record low last year the latest worrying statistic in a decadeslong decline that the country authorities have failed to reverse despite their extensive efforts.

# %%
# Information about The Guardian:

guardian = textual_data[1]

print(f"Found {len(guardian)} articles for The Guardian:")
     
show_articles = 1
show_percentage = 0.2
for i in range(show_articles):
    print(f"\nArticle Nr. {i}:")
    print(guardian[i][:int(len(guardian[i]) * show_percentage)], "...")
# Out:
# Found 21 articles for The Guardian:
#
# Article Nr. 0:
# Officials meet in Tokyo to discuss concerns at China cooperation with Russia and Japan military buildup Chinese and Japanese officials met in Tokyo on Wednesday for formal security talks for the first time in four years in a meeting aimed at stabilising increasingly strained relations. In Japan national security strategy released in December China was described as the greatest strategic challenge to Japan peace and security. Both sides expressed concerns at Wednesday meeting. China said it was troubled by Japan military buildup while Tokyo is worried about China suspected use of spy balloons as well as Chinese  ...

# %%
# Information about Wikipedia - Wikipedia articles contain only the description 

wikipedia = textual_data[2]

print(f"Found {len(wikipedia)} article for Wikipedia:")
      
show_articles = 1  
for i in range(show_articles):
    print(f"\nArticle Nr. {i}:")
    print(wikipedia[i])
# Out:
# Found 1 article for Wikipedia:
#
# Article Nr. 0:
# The prime minister of Japan is the head of the executive branch and chief minister of the government of Japan. This is a list of prime ministers of Japan from when the first Japanese prime minister Itō Hirobumi took office in 1885 until the present day. The office is currently held by Fumio Kishida. Those prime ministers under the Meiji Constitution had a mandate from the emperor. The electoral mandates shown are for the lower house of the Imperial Diet that was not constitutionally guaranteed to have any influence on the appointment of the prime minister.

# %% [markdown]
# ## 3.3 <u>Preparing the data</u>
#
# <p style='text-align: justify;'>In order to use the collected data, it is important to put it into a consistent, clean form that is useful for BERT. The reason for this is contamination of texts, which can affect subsequent predictions for the [MASK] token. In particular, the cleanup of texts is done by a function of the pipeline, which consists of a variety of regular expressions that filter out or transform various anomalies and impurities. Regular expressions are particularly suitable for textual data for data preparation, as it is possible to specify a uniform syntax of texts through these rules. All impurities, such as elements of page description languages, acronyms, abbreviations, and formatting errors that violate these rules are either replaced or transformed into a different form. This step is important because only a syntactically clean block of text can be broken down into error-free individual sentences and inserted into a list.</p>
#
# <p style='text-align: justify;'>Note: Due to the structure of the news_loader and for simplification reasons, this step is automatically performed by the text_clean_up function when loading the articles. </p>
#
# <p style='text-align: justify;'>For further preparation, we also need to split the found articles into sentences and merge them into a one-dimensional list. For this step we will use the split and merge functions from our package. </p>

# %%
split_data = BERTuality.nltk_sentence_split(textual_data)
merged_data = BERTuality.merge_sentences(split_data)

print(f"Found a total of {len(merged_data)} possible input sentences.")
# Out:
# Found a total of 856 possible input sentences.

# %%
api_sentences = pd.DataFrame(merged_data, columns=["Merged API Sentences"])
api_sentences.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'center')]) ])
# Out:
# <style type="text/css">
# #T_ad1e7 th {
#   text-align: center;
# }
# #T_ad1e7_row0_col0, #T_ad1e7_row1_col0, #T_ad1e7_row2_col0, #T_ad1e7_row3_col0, #T_ad1e7_row4_col0, #T_ad1e7_row5_col0, #T_ad1e7_row6_col0, #T_ad1e7_row7_col0, #T_ad1e7_row8_col0, #T_ad1e7_row9_col0, #T_ad1e7_row10_col0, #T_ad1e7_row11_col0, #T_ad1e7_row12_col0, #T_ad1e7_row13_col0, #T_ad1e7_row14_col0, #T_ad1e7_row15_col0, #T_ad1e7_row16_col0, #T_ad1e7_row17_col0, #T_ad1e7_row18_col0, #T_ad1e7_row19_col0, #T_ad1e7_row20_col0, #T_ad1e7_row21_col0, #T_ad1e7_row22_col0, #T_ad1e7_row23_col0, #T_ad1e7_row24_col0, #T_ad1e7_row25_col0, #T_ad1e7_row26_col0, #T_ad1e7_row27_col0, #T_ad1e7_row28_col0, #T_ad1e7_row29_col0, #T_ad1e7_row30_col0, #T_ad1e7_row31_col0, #T_ad1e7_row32_col0, #T_ad1e7_row33_col0, #T_ad1e7_row34_col0, #T_ad1e7_row35_col0, #T_ad1e7_row36_col0, #T_ad1e7_row37_col0, #T_ad1e7_row38_col0, #T_ad1e7_row39_col0, #T_ad1e7_row40_col0, #T_ad1e7_row41_col0, #T_ad1e7_row42_col0, #T_ad1e7_row43_col0, #T_ad1e7_row44_col0, #T_ad1e7_row45_col0, #T_ad1e7_row46_col0, #T_ad1e7_row47_col0, #T_ad1e7_row48_col0, #T_ad1e7_row49_col0, #T_ad1e7_row50_col0, #T_ad1e7_row51_col0, #T_ad1e7_row52_col0, #T_ad1e7_row53_col0, #T_ad1e7_row54_col0, #T_ad1e7_row55_col0, #T_ad1e7_row56_col0, #T_ad1e7_row57_col0, #T_ad1e7_row58_col0, #T_ad1e7_row59_col0, #T_ad1e7_row60_col0, #T_ad1e7_row61_col0, #T_ad1e7_row62_col0, #T_ad1e7_row63_col0, #T_ad1e7_row64_col0, #T_ad1e7_row65_col0, #T_ad1e7_row66_col0, #T_ad1e7_row67_col0, #T_ad1e7_row68_col0, #T_ad1e7_row69_col0, #T_ad1e7_row70_col0, #T_ad1e7_row71_col0, #T_ad1e7_row72_col0, #T_ad1e7_row73_col0, #T_ad1e7_row74_col0, #T_ad1e7_row75_col0, #T_ad1e7_row76_col0, #T_ad1e7_row77_col0, #T_ad1e7_row78_col0, #T_ad1e7_row79_col0, #T_ad1e7_row80_col0, #T_ad1e7_row81_col0, #T_ad1e7_row82_col0, #T_ad1e7_row83_col0, #T_ad1e7_row84_col0, #T_ad1e7_row85_col0, #T_ad1e7_row86_col0, #T_ad1e7_row87_col0, #T_ad1e7_row88_col0, #T_ad1e7_row89_col0, #T_ad1e7_row90_col0, #T_ad1e7_row91_col0, #T_ad1e7_row92_col0, #T_ad1e7_row93_col0, #T_ad1e7_row94_col0, #T_ad1e7_row95_col0, #T_ad1e7_row96_col0, #T_ad1e7_row97_col0, #T_ad1e7_row98_col0, #T_ad1e7_row99_col0, #T_ad1e7_row100_col0, #T_ad1e7_row101_col0, #T_ad1e7_row102_col0, #T_ad1e7_row103_col0, #T_ad1e7_row104_col0, #T_ad1e7_row105_col0, #T_ad1e7_row106_col0, #T_ad1e7_row107_col0, #T_ad1e7_row108_col0, #T_ad1e7_row109_col0, #T_ad1e7_row110_col0, #T_ad1e7_row111_col0, #T_ad1e7_row112_col0, #T_ad1e7_row113_col0, #T_ad1e7_row114_col0, #T_ad1e7_row115_col0, #T_ad1e7_row116_col0, #T_ad1e7_row117_col0, #T_ad1e7_row118_col0, #T_ad1e7_row119_col0, #T_ad1e7_row120_col0, #T_ad1e7_row121_col0, #T_ad1e7_row122_col0, #T_ad1e7_row123_col0, #T_ad1e7_row124_col0, #T_ad1e7_row125_col0, #T_ad1e7_row126_col0, #T_ad1e7_row127_col0, #T_ad1e7_row128_col0, #T_ad1e7_row129_col0, #T_ad1e7_row130_col0, #T_ad1e7_row131_col0, #T_ad1e7_row132_col0, #T_ad1e7_row133_col0, #T_ad1e7_row134_col0, #T_ad1e7_row135_col0, #T_ad1e7_row136_col0, #T_ad1e7_row137_col0, #T_ad1e7_row138_col0, #T_ad1e7_row139_col0, #T_ad1e7_row140_col0, #T_ad1e7_row141_col0, #T_ad1e7_row142_col0, #T_ad1e7_row143_col0, #T_ad1e7_row144_col0, #T_ad1e7_row145_col0, #T_ad1e7_row146_col0, #T_ad1e7_row147_col0, #T_ad1e7_row148_col0, #T_ad1e7_row149_col0, #T_ad1e7_row150_col0, #T_ad1e7_row151_col0, #T_ad1e7_row152_col0, #T_ad1e7_row153_col0, #T_ad1e7_row154_col0, #T_ad1e7_row155_col0, #T_ad1e7_row156_col0, #T_ad1e7_row157_col0, #T_ad1e7_row158_col0, #T_ad1e7_row159_col0, #T_ad1e7_row160_col0, #T_ad1e7_row161_col0, #T_ad1e7_row162_col0, #T_ad1e7_row163_col0, #T_ad1e7_row164_col0, #T_ad1e7_row165_col0, #T_ad1e7_row166_col0, #T_ad1e7_row167_col0, #T_ad1e7_row168_col0, #T_ad1e7_row169_col0, #T_ad1e7_row170_col0, #T_ad1e7_row171_col0, #T_ad1e7_row172_col0, #T_ad1e7_row173_col0, #T_ad1e7_row174_col0, #T_ad1e7_row175_col0, #T_ad1e7_row176_col0, #T_ad1e7_row177_col0, #T_ad1e7_row178_col0, #T_ad1e7_row179_col0, #T_ad1e7_row180_col0, #T_ad1e7_row181_col0, #T_ad1e7_row182_col0, #T_ad1e7_row183_col0, #T_ad1e7_row184_col0, #T_ad1e7_row185_col0, #T_ad1e7_row186_co ...

# %% [markdown]
# <p style='text-align: justify;'>Theoretically, it is already possible from this step to pass the list of collected sentences to BERT and to generate a prediction for the searched [MASK] token for each individual sentence. However, this should not be done, since at this point all sentences from the data sources are unfiltered. These unfiltered sentences may contain irrelevant information that worsens the prediction and drastically increases the pipeline processing time. Therefore, the amount of sentences must be reduced to optimal sentences in the next step of the pipeline.</p>

# %% [markdown]
# ## 3.4 <u>Finding optimal sentences</u>
#
# <p style='text-align: justify;'>In addition to cleaning through data preparation, the query module from this chapter offers the possibility of filtering for optimal data and modifying it if necessary. The goal is to reduce the amount of sentences to optimal input sentences. This should on the one hand increase the performance and on the other hand improve the quality of the prediction.</p>

# %% [markdown]
# ### 3.4.1 <u>Extraction Query</u>
#
# <p style='text-align: justify;'>We introduce the extraction query into the query module to remove irrelevant sentences from the dataset obtained so far. Only sentences that contain the respective keywords are considered. However, not all keywords must be contained in a sentence, otherwise this leads to a too strict data filtering.</p>
#
# <p style='text-align: justify;'>With a minimum number of keywords defined by the subset_size variable, subsets are formed. The subsets contain records with partially existing keywords. A set can contain variations of a keyword. If none of the keywords are present in a sentence, the sentence is removed from the set of input sentences.</p>

# %%
# let's define a subset_size
subset_size=2

# %%
# and have a look at the created subsets of our keywords
subsets = BERTuality.create_subsets(keywords, subset_size=subset_size)

print(f"Keywords:      {keywords}\n")
for i, j in enumerate(subsets):
    print(f"   {i}. Subset = {j}")
# Out:
# Keywords:      ['Prime', 'minister', 'Japan']
#
#    0. Subset = ['Prime', 'minister']
#    1. Subset = ['Prime', 'Japan']
#    2. Subset = ['minister', 'Japan']

# %%
extraction_query = BERTuality.filter_for_keyword_subsets(input_sentences=merged_data, 
                                                         keywords=keywords, 
                                                         tokenizer=tokenizer, 
                                                         subset_size=subset_size, 
                                                         duplicates=False)

print(f"Found a total of {len(extraction_query)} input sentences.")
# Out:
# Found a total of 78 input sentences.

# %%
extraction_df = pd.DataFrame(extraction_query, columns=["Extraction Query"])
extraction_df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'center')]) ])
# Out:
# <style type="text/css">
# #T_131b1 th {
#   text-align: center;
# }
# #T_131b1_row0_col0, #T_131b1_row1_col0, #T_131b1_row2_col0, #T_131b1_row3_col0, #T_131b1_row4_col0, #T_131b1_row5_col0, #T_131b1_row6_col0, #T_131b1_row7_col0, #T_131b1_row8_col0, #T_131b1_row9_col0, #T_131b1_row10_col0, #T_131b1_row11_col0, #T_131b1_row12_col0, #T_131b1_row13_col0, #T_131b1_row14_col0, #T_131b1_row15_col0, #T_131b1_row16_col0, #T_131b1_row17_col0, #T_131b1_row18_col0, #T_131b1_row19_col0, #T_131b1_row20_col0, #T_131b1_row21_col0, #T_131b1_row22_col0, #T_131b1_row23_col0, #T_131b1_row24_col0, #T_131b1_row25_col0, #T_131b1_row26_col0, #T_131b1_row27_col0, #T_131b1_row28_col0, #T_131b1_row29_col0, #T_131b1_row30_col0, #T_131b1_row31_col0, #T_131b1_row32_col0, #T_131b1_row33_col0, #T_131b1_row34_col0, #T_131b1_row35_col0, #T_131b1_row36_col0, #T_131b1_row37_col0, #T_131b1_row38_col0, #T_131b1_row39_col0, #T_131b1_row40_col0, #T_131b1_row41_col0, #T_131b1_row42_col0, #T_131b1_row43_col0, #T_131b1_row44_col0, #T_131b1_row45_col0, #T_131b1_row46_col0, #T_131b1_row47_col0, #T_131b1_row48_col0, #T_131b1_row49_col0, #T_131b1_row50_col0, #T_131b1_row51_col0, #T_131b1_row52_col0, #T_131b1_row53_col0, #T_131b1_row54_col0, #T_131b1_row55_col0, #T_131b1_row56_col0, #T_131b1_row57_col0, #T_131b1_row58_col0, #T_131b1_row59_col0, #T_131b1_row60_col0, #T_131b1_row61_col0, #T_131b1_row62_col0, #T_131b1_row63_col0, #T_131b1_row64_col0, #T_131b1_row65_col0, #T_131b1_row66_col0, #T_131b1_row67_col0, #T_131b1_row68_col0, #T_131b1_row69_col0, #T_131b1_row70_col0, #T_131b1_row71_col0, #T_131b1_row72_col0, #T_131b1_row73_col0, #T_131b1_row74_col0, #T_131b1_row75_col0, #T_131b1_row76_col0, #T_131b1_row77_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_131b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_131b1_level0_col0" class="col_heading level0 col0" >Extraction Query</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_131b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_131b1_row0_col0" class="data row0 col0" >South Korean President Yoon Suk Yeol departed South Korea on Thursday for Tokyo to meet with Prime Minister Fumio Kishida the first such summit on Japanese soil in more than a decade.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_131b1_row1_col0" class="data row1 col0" >The other toasted a close friendship with MoscowOn Tuesday Japan prime minister laid a wreath for the dead outside a church in the blasted Ukrainian town of Bucha.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_131b1_row2_col0" class="data row2 col0" >Japanese Prime Minister Fumio Kishida began a surprise visit to Ukraine early Tuesday hours after Chinese President Xi Jinping arrived in Russia.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_131b1_row3_col0" class="data row3 col0" >College football Mexican cola and muffins United Kingdom prime minister has plenty to talk about in private hour at Aukus It is common for British and American leaders to try to show the special relationship between their two countries extends to them personally.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_131b1_row4_col0" class="data row4 col0" >Sen. Mike Lee of Utah demanded that Prime Minister Fumio Kishida release a U. S. Navy lieutenant jailed for a deadly car crash.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_131b1_row5_col0" class="data row5 col0" >Japanese prime minister to show olidarity' with Ukraine in visit that coincides with Chinese leader Moscow trip.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_131b1_row6_col0" class="data row6 col0" >Japan Prime Minister Kishida making surprise visit to Ukraine to meet Zelensky CNN.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_131b1_row7_col0" class="data row7 col0" >Japan Prime Minister Kishida bound for Ukraine Zelenskyy meeting ABC News.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_131b1_row8_col0" class="data row8 col0" >Before being elected as the President Ram Chandra Poudel has served as Nepal Deputy Prime Minister cabinet minister and Speaker.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_131b1_row9_col0" class="data row9 col0" >Japan Prime Minister Kishida Heads To Ukraine For Talks With Zelenskyy Russia Ukraine War Updates News18 CNNNews18.Japan Prime Minister Kishida making surprise visit to Ukraine to meet Zelensky CNN.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_131b1_row10_col0" class="data row10 col0" >Japanese Prime Minister Fumio Kishida and South Korean.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_131b1_row11_col0" class="data row11 col0" >While in Japan Banga met virtually with South Koreas Deputy Prime Minister and Finance Minister Choo KyungHo.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_131b1_row12_col0" class="data row12 col0" >Japanese Prime Minister Fumio Kishida began a surprise visit to Ukraine early Tuesday hours after Chinese President Xi Jinping.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_131b1_row13_col0" class="data row13 col0" >South Korean President Yoon to meet Japanese Prime Minister Kishida The Washington Post.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_131b1_row14_col0" class="data row14 col0" >The launch came just before South Korean President Yoon Suk Yeol was to meet with Japanese Prime Minister Fumio Kishida in Tokyo.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_131b1_row15_col0" class="data row15 col0" >Japan and Germany pledged closer defence ties and cooperation on diversifying supply chains as Chancellor Olaf Scholz and Prime Minister Fumio Kishida met.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_131b1_row16_col0" class="data row16 col0" >Japanese Prime Minister Fumio Kishida on Monday called India vital to ensuring a free and open IndoPacific after talks with his counterpart touching.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_131b1_row17_col0" class="data row17 col0" >Japanese Prime Minister Fumio Kishida will meet Ukrainian President Volodymyr Zelensky during a surprise visit to Kyiv on Tuesday to offer solidarity and.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_131b1_row18_col0" class="data row18 col0" >Japan Prime Minister Fumio Kishida on Monday invited his Indian counterpart Narendra Modi for the Group of Seven major industrial nations' summit in May.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_131b1_row19_col0" class="data row19 col0" >South Korean President Yoon Suk Yeol will travel to Japan for talks on Thursday with Prime Minister Fumio Kishida a South Korean official said days after.</td>
#     </tr>
#     <tr>
#       <th id="T_131b1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_131b1_row20_col0" class="data r

# %% [markdown]
# ### 3.4.2 <u>Similarity Query</u>
#
# <p style='text-align: justify;'>We introduce the similarity query in the query module to reduce another portion of the input sentences to generate an improved prediction for the [MASK] token. We achieve this goal by only allowing identical or similar sentences that exceed a certain threshold as input to BERT. Similar inputs in our case are sentences that have a similarity to our [MASK] sentence. To be able to determine a similarity score, we need the vector of the [MASK] sentence and the vector of an input sentence. Using cosine similarity, a similarity value is calculated between the [MASK] sentence and the input sentence. This method is repeated for each input sentence found to determine a similarity score between -1 and 1 for each. Here -1 stands for no similarity, 0 for an independent sentence and 1 for an identical sentence. By using a predefined threshold, input records with insufficient similarity can be filtered out. This threshold is also called similarity_score (=sim_score) in BERTuality and should be a small value above 0 when using the extraction query.</p>

# %%
similarity_query_tuple = BERTuality.similarity_filter(mask_sentence, extraction_query, sim_score=0.25, return_tuples=True)
print(f"Found a total of {len(similarity_query_tuple)} input sentences.")
# Out:
# Found a total of 37 input sentences.

# %%
similarity_df = pd.DataFrame(similarity_query_tuple, columns=["Similarity Score", "Similarity Query"])
similarity_df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'center')]) ])
# Out:
# <style type="text/css">
# #T_187f2 th {
#   text-align: center;
# }
# #T_187f2_row0_col0, #T_187f2_row0_col1, #T_187f2_row1_col0, #T_187f2_row1_col1, #T_187f2_row2_col0, #T_187f2_row2_col1, #T_187f2_row3_col0, #T_187f2_row3_col1, #T_187f2_row4_col0, #T_187f2_row4_col1, #T_187f2_row5_col0, #T_187f2_row5_col1, #T_187f2_row6_col0, #T_187f2_row6_col1, #T_187f2_row7_col0, #T_187f2_row7_col1, #T_187f2_row8_col0, #T_187f2_row8_col1, #T_187f2_row9_col0, #T_187f2_row9_col1, #T_187f2_row10_col0, #T_187f2_row10_col1, #T_187f2_row11_col0, #T_187f2_row11_col1, #T_187f2_row12_col0, #T_187f2_row12_col1, #T_187f2_row13_col0, #T_187f2_row13_col1, #T_187f2_row14_col0, #T_187f2_row14_col1, #T_187f2_row15_col0, #T_187f2_row15_col1, #T_187f2_row16_col0, #T_187f2_row16_col1, #T_187f2_row17_col0, #T_187f2_row17_col1, #T_187f2_row18_col0, #T_187f2_row18_col1, #T_187f2_row19_col0, #T_187f2_row19_col1, #T_187f2_row20_col0, #T_187f2_row20_col1, #T_187f2_row21_col0, #T_187f2_row21_col1, #T_187f2_row22_col0, #T_187f2_row22_col1, #T_187f2_row23_col0, #T_187f2_row23_col1, #T_187f2_row24_col0, #T_187f2_row24_col1, #T_187f2_row25_col0, #T_187f2_row25_col1, #T_187f2_row26_col0, #T_187f2_row26_col1, #T_187f2_row27_col0, #T_187f2_row27_col1, #T_187f2_row28_col0, #T_187f2_row28_col1, #T_187f2_row29_col0, #T_187f2_row29_col1, #T_187f2_row30_col0, #T_187f2_row30_col1, #T_187f2_row31_col0, #T_187f2_row31_col1, #T_187f2_row32_col0, #T_187f2_row32_col1, #T_187f2_row33_col0, #T_187f2_row33_col1, #T_187f2_row34_col0, #T_187f2_row34_col1, #T_187f2_row35_col0, #T_187f2_row35_col1, #T_187f2_row36_col0, #T_187f2_row36_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_187f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_187f2_level0_col0" class="col_heading level0 col0" >Similarity Score</th>
#       <th id="T_187f2_level0_col1" class="col_heading level0 col1" >Similarity Query</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_187f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_187f2_row0_col0" class="data row0 col0" >0.267162</td>
#       <td id="T_187f2_row0_col1" class="data row0 col1" >South Korean President Yoon Suk Yeol departed South Korea on Thursday for Tokyo to meet with Prime Minister Fumio Kishida the first such summit on Japanese soil in more than a decade.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_187f2_row1_col0" class="data row1 col0" >0.291097</td>
#       <td id="T_187f2_row1_col1" class="data row1 col1" >The other toasted a close friendship with MoscowOn Tuesday Japan prime minister laid a wreath for the dead outside a church in the blasted Ukrainian town of Bucha.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_187f2_row2_col0" class="data row2 col0" >0.283896</td>
#       <td id="T_187f2_row2_col1" class="data row2 col1" >Japanese Prime Minister Fumio Kishida began a surprise visit to Ukraine early Tuesday hours after Chinese President Xi Jinping arrived in Russia.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_187f2_row3_col0" class="data row3 col0" >0.261317</td>
#       <td id="T_187f2_row3_col1" class="data row3 col1" >College football Mexican cola and muffins United Kingdom prime minister has plenty to talk about in private hour at Aukus It is common for British and American leaders to try to show the special relationship between their two countries extends to them personally.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_187f2_row4_col0" class="data row4 col0" >0.437871</td>
#       <td id="T_187f2_row4_col1" class="data row4 col1" >Japanese prime minister to show olidarity' with Ukraine in visit that coincides with Chinese leader Moscow trip.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_187f2_row5_col0" class="data row5 col0" >0.282727</td>
#       <td id="T_187f2_row5_col1" class="data row5 col1" >Japan Prime Minister Kishida making surprise visit to Ukraine to meet Zelensky CNN.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_187f2_row6_col0" class="data row6 col0" >0.295928</td>
#       <td id="T_187f2_row6_col1" class="data row6 col1" >Japan Prime Minister Kishida bound for Ukraine Zelenskyy meeting ABC News.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_187f2_row7_col0" class="data row7 col0" >0.362052</td>
#       <td id="T_187f2_row7_col1" class="data row7 col1" >Japan Prime Minister Kishida Heads To Ukraine For Talks With Zelenskyy Russia Ukraine War Updates News18 CNNNews18.Japan Prime Minister Kishida making surprise visit to Ukraine to meet Zelensky CNN.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_187f2_row8_col0" class="data row8 col0" >0.505551</td>
#       <td id="T_187f2_row8_col1" class="data row8 col1" >Japanese Prime Minister Fumio Kishida and South Korean.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_187f2_row9_col0" class="data row9 col0" >0.401756</td>
#       <td id="T_187f2_row9_col1" class="data row9 col1" >While in Japan Banga met virtually with South Koreas Deputy Prime Minister and Finance Minister Choo KyungHo.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_187f2_row10_col0" class="data row10 col0" >0.289914</td>
#       <td id="T_187f2_row10_col1" class="data row10 col1" >Japanese Prime Minister Fumio Kishida began a surprise visit to Ukraine early Tuesday hours after Chinese President Xi Jinping.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_187f2_row11_col0" class="data row11 col0" >0.346549</td>
#       <td id="T_187f2_row11_col1" class="data row11 col1" >South Korean President Yoon to meet Japanese Prime Minister Kishida The Washington Post.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_187f2_row12_col0" class="data row12 col0" >0.328675</td>
#       <td id="T_187f2_row12_col1" class="data row12 col1" >The launch came just before South Korean President Yoon Suk Yeol was to meet with Japanese Prime Minister Fumio Kishida in Tokyo.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_187f2_row13_col0" class="data row13 col0" >0.274615</td>
#       <td id="T_187f2_row13_col1" class="data row13 col1" >Japan and Germany pledged closer defence ties and cooperation on diversifying supply chains as Chancellor Olaf Scholz and Prime Minister Fumio Kishida met.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_187f2_row14_col0" class="data row14 col0" >0.286478</td>
#       <td id="T_187f2_row14_col1" class="data row14 col1" >Japanese Prime Minister Fumio Kishida will meet Ukrainian President Volodymyr Zelensky during a surprise visit to Kyiv on Tuesday to offer solidarity and.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_187f2_row15_col0" class="data row15 col0" >0.364286</td>
#       <td id="T_187f2_row15_col1" class="data row15 col1" >Japan Prime Minister Fumio Kishida on Monday invited his Indian counterpart Narendra Modi for the Group of Seven major industrial nations' summit in May.</td>
#     </tr>
#     <tr>
#       <th id="T_187f2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_187f2_row16_col0" class="data row16 col0" >0.253584</td>
#       <td id="T_187f2_row16_col1" cl

# %%
# add all sentences into a sperarate list - needed because we used return_tuples
similarity_query = [i[1] for i in similarity_query_tuple]

# %% [markdown]
# ### 3.4.3 <u>Focus Query</u>
#
# <p style='text-align: justify;'>We introduce the focus query into the query module to remove contextually unimportant information from sentences that are too long. Since there is usually only one short core information in a sentence that we need for BERTuality, it is important to extract just this core information from the sentence. Any additional information beyond this core may have a negative impact on the prediction result. Therefore, the focus query uses the previously created keywords that must be included in our sentence. We also assume that the information to be predicted must occur near the keywords we are looking for.</p>
#
#
# <p style='text-align: justify;'>However, to separate irrelevant from relevant parts of the sentence, we first determine the first positions of each keyword in the sentence. This span between the found positions forms our core information. In the next step, we truncate all words outside this interval and classify them as irrelevant for now. As mentioned earlier, our relevant information is located near the keywords, which means that some of the information may be outside the core. Therefore, after the truncation process, we again append a part of the original sentence to our core information. We refer to this appended part as the padding of the focus query. This padding can be defined by a value of our choice and includes the number of words appended to the left and right.</p>

# %%
focus_query = BERTuality.keyword_focus(similarity_query, keywords, padding=2)

# %%
sim_len = sum([len(i) for i in similarity_query])
foc_len = sum([len(i) for i in focus_query])

print("Total sum of characters in the Similarity Query:", sim_len)
print("Total sum of characters in the Focus Query:     ", foc_len)
print(f"\nWe achieved a reduction of {sim_len - foc_len} characters in {len(focus_query)} sentences!")
# Out:
# Total sum of characters in the Similarity Query: 5670
# Total sum of characters in the Focus Query:      2291
#
# We achieved a reduction of 3379 characters in 37 sentences!

# %%
focus_df = pd.DataFrame(focus_query, columns=["Focus Query"])
focus_df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'center')]) ])
# Out:
# <style type="text/css">
# #T_f0ed9 th {
#   text-align: center;
# }
# #T_f0ed9_row0_col0, #T_f0ed9_row1_col0, #T_f0ed9_row2_col0, #T_f0ed9_row3_col0, #T_f0ed9_row4_col0, #T_f0ed9_row5_col0, #T_f0ed9_row6_col0, #T_f0ed9_row7_col0, #T_f0ed9_row8_col0, #T_f0ed9_row9_col0, #T_f0ed9_row10_col0, #T_f0ed9_row11_col0, #T_f0ed9_row12_col0, #T_f0ed9_row13_col0, #T_f0ed9_row14_col0, #T_f0ed9_row15_col0, #T_f0ed9_row16_col0, #T_f0ed9_row17_col0, #T_f0ed9_row18_col0, #T_f0ed9_row19_col0, #T_f0ed9_row20_col0, #T_f0ed9_row21_col0, #T_f0ed9_row22_col0, #T_f0ed9_row23_col0, #T_f0ed9_row24_col0, #T_f0ed9_row25_col0, #T_f0ed9_row26_col0, #T_f0ed9_row27_col0, #T_f0ed9_row28_col0, #T_f0ed9_row29_col0, #T_f0ed9_row30_col0, #T_f0ed9_row31_col0, #T_f0ed9_row32_col0, #T_f0ed9_row33_col0, #T_f0ed9_row34_col0, #T_f0ed9_row35_col0, #T_f0ed9_row36_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_f0ed9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0ed9_level0_col0" class="col_heading level0 col0" >Focus Query</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0ed9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0ed9_row0_col0" class="data row0 col0" >meet with prime minister fumio kishida the first such summit on japan soil in.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0ed9_row1_col0" class="data row1 col0" >moscowon tuesday japan prime minister laid a.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f0ed9_row2_col0" class="data row2 col0" >japan prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f0ed9_row3_col0" class="data row3 col0" >united kingdom prime minister has plenty.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f0ed9_row4_col0" class="data row4 col0" >japan prime minister to show.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f0ed9_row5_col0" class="data row5 col0" >japan prime minister kishida making.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f0ed9_row6_col0" class="data row6 col0" >japan prime minister kishida bound.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f0ed9_row7_col0" class="data row7 col0" >japan prime minister kishida heads.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f0ed9_row8_col0" class="data row8 col0" >japan prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f0ed9_row9_col0" class="data row9 col0" >while in japan banga met virtually with south koreas deputy prime minister and finance.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f0ed9_row10_col0" class="data row10 col0" >japan prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f0ed9_row11_col0" class="data row11 col0" >to meet japan prime minister kishida the.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f0ed9_row12_col0" class="data row12 col0" >meet with japan prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f0ed9_row13_col0" class="data row13 col0" >japan and germany pledged closer defence ties and cooperation on diversifying supply chains as chancellor olaf scholz and prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f0ed9_row14_col0" class="data row14 col0" >japan prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f0ed9_row15_col0" class="data row15 col0" >japan prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f0ed9_row16_col0" class="data row16 col0" >travel to japan for talks on thursday with prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f0ed9_row17_col0" class="data row17 col0" >scholz and japan prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f0ed9_row18_col0" class="data row18 col0" >japanese prime minister fumio kishida is hoping to hold a summit meeting with south korean counterpart yoon suk yeol next week the head of japan ruling.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f0ed9_row19_col0" class="data row19 col0" >the indian prime minister will attend the elite gathering hosted by japan in hiroshima.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f0ed9_row20_col0" class="data row20 col0" >japan prime minister kishida fumio.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f0ed9_row21_col0" class="data row21 col0" >called for japan to join his efforts to improve bilateral relations strained by historical grievances as he prepares to travel to tokyo for a highly anticipated summit with japanese prime minister fumio kishida.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f0ed9_row22_col0" class="data row22 col0" >a former prime minister is aimed.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f0ed9_row23_col0" class="data row23 col0" >the day prime minister narendra modi and kishida are also set to discuss priorities for indias presidency of g20 and japan presidency of.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f0ed9_row24_col0" class="data row24 col0" >the prime minister anthony albanese.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f0ed9_row25_col0" class="data row25 col0" >australia former prime minister urges new.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f0ed9_row26_col0" class="data row26 col0" >speaking in japan in her first public speech since her resignation as prime minister truss called.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f0ed9_row27_col0" class="data row27 col0" >interventions by prime minister should be.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f0ed9_row28_col0" class="data row28 col0" >choices as prime minister and she is expected to also speak at a conference in japan on the.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_f0ed9_row29_col0" class="data row29 col0" >other former prime minister australia scott.</td>
#     </tr>
#     <tr>
#       <th id="T_f0ed9_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_f0ed9_row30_col0" class="data row30 col0" >have a prime minister of aian.</td>
#     </tr>
#     <tr>

# %% [markdown]
# ## 3.5 <u>Predictions with BERTuality</u>
#
# <p style='text-align: justify;'>Finally, the [MASK] sentence and the actuality-related input sentences created by the BERTuality pipeline are passed to BERT. Ideally, the selected input sentences contain the maximum relevant content of all sentences from the data source.</p>
#
#
# ### 3.5.1 <u>Input Prediction</u>
#
# <p style='text-align: justify;'>By passing the inputs to the fill mask pipeline a prediction for the [MASK] token is generated. This may differ from the prediction without any additional input. The reason for this is the priming of BERT with the input sentences created from the BERTuality pipeline described in chapter 2.2. Therefore, throughout the BERTuality pipeline, our goal is to find optimally suitable input sentences. This is because the more similar the input sentence is to the [MASK] sentence, the higher the probability that the sentence also contains the correct information to be predicted. In order to be able to generate a prediction, the corresponding input sentences from the BERTuality pipeline are passed to BERT in addition to the [MASK] sentence in the optimal input form already explained.</p>
#
# <p style='text-align: justify;'>To catch the case of a non-optimal input sentence, so that no wrong prediction is risked, all found sentences are used as inputs for BERT. Thus, the [MASK] token is predicted once for each of the included input sentences.</p>

# %%
# the make_predictions function is equal to the "fill_mask" pipeline from chapter 2, but also returns a DataFrame
input_prediction = BERTuality.make_predictions(mask_sentence, focus_query, model, tokenizer)

# %%
# let's have a look at the first 5 predictions of the input prediction
input_prediction_df = input_prediction[["masked", "input", "token1", "score1"]].head()
input_prediction_df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'center')]) ])
# Out:
# <style type="text/css">
# #T_abd38 th {
#   text-align: center;
# }
# #T_abd38_row0_col0, #T_abd38_row0_col1, #T_abd38_row0_col2, #T_abd38_row0_col3, #T_abd38_row1_col0, #T_abd38_row1_col1, #T_abd38_row1_col2, #T_abd38_row1_col3, #T_abd38_row2_col0, #T_abd38_row2_col1, #T_abd38_row2_col2, #T_abd38_row2_col3, #T_abd38_row3_col0, #T_abd38_row3_col1, #T_abd38_row3_col2, #T_abd38_row3_col3, #T_abd38_row4_col0, #T_abd38_row4_col1, #T_abd38_row4_col2, #T_abd38_row4_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_abd38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abd38_level0_col0" class="col_heading level0 col0" >masked</th>
#       <th id="T_abd38_level0_col1" class="col_heading level0 col1" >input</th>
#       <th id="T_abd38_level0_col2" class="col_heading level0 col2" >token1</th>
#       <th id="T_abd38_level0_col3" class="col_heading level0 col3" >score1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abd38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abd38_row0_col0" class="data row0 col0" >Prime minister [MASK] is the leader of Japan.</td>
#       <td id="T_abd38_row0_col1" class="data row0 col1" >meet with prime minister fumio kishida the first such summit on japan soil in.</td>
#       <td id="T_abd38_row0_col2" class="data row0 col2" >abe</td>
#       <td id="T_abd38_row0_col3" class="data row0 col3" >0.432130</td>
#     </tr>
#     <tr>
#       <th id="T_abd38_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_abd38_row1_col0" class="data row1 col0" >Prime minister [MASK] is the leader of Japan.</td>
#       <td id="T_abd38_row1_col1" class="data row1 col1" >moscowon tuesday japan prime minister laid a.</td>
#       <td id="T_abd38_row1_col2" class="data row1 col2" >who</td>
#       <td id="T_abd38_row1_col3" class="data row1 col3" >0.477845</td>
#     </tr>
#     <tr>
#       <th id="T_abd38_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_abd38_row2_col0" class="data row2 col0" >Prime minister [MASK] is the leader of Japan.</td>
#       <td id="T_abd38_row2_col1" class="data row2 col1" >japan prime minister fumio kishida.</td>
#       <td id="T_abd38_row2_col2" class="data row2 col2" >he</td>
#       <td id="T_abd38_row2_col3" class="data row2 col3" >0.422209</td>
#     </tr>
#     <tr>
#       <th id="T_abd38_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_abd38_row3_col0" class="data row3 col0" >Prime minister [MASK] is the leader of Japan.</td>
#       <td id="T_abd38_row3_col1" class="data row3 col1" >united kingdom prime minister has plenty.</td>
#       <td id="T_abd38_row3_col2" class="data row3 col2" >tanaka</td>
#       <td id="T_abd38_row3_col3" class="data row3 col3" >0.211324</td>
#     </tr>
#     <tr>
#       <th id="T_abd38_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_abd38_row4_col0" class="data row4 col0" >Prime minister [MASK] is the leader of Japan.</td>
#       <td id="T_abd38_row4_col1" class="data row4 col1" >japan prime minister to show.</td>
#       <td id="T_abd38_row4_col2" class="data row4 col2" >who</td>
#       <td id="T_abd38_row4_col3" class="data row4 col3" >0.815423</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <p style='text-align: justify;'>To select the correct word from the list of predictions, the scores of the same word occurrences are summed. This is what we call sum_up_score and is consequently the decision criterion for the [MASK] token, where the word with the highest value is selected for the [MASK] token. Nevertheless, it is not possible for the input prediction to predict every single token for the [MASK] token.</p>

# %%
# here you can have a look at a summary of the top predictions
BERTuality.simple_pred_results(input_prediction).head()
# Out:
#     Token  Frequency  max_score  min_score  mean_score  sum_up_score
# 0     who         10   0.815423   0.282997    0.565108      5.651080
# 1      he         10   0.424347   0.185562    0.347023      3.470225
# 2     abe          7   0.484453   0.115956    0.337288      2.361017
# 3  tanaka          5   0.322877   0.147092    0.211666      1.058330
# 4  making          1   0.979401   0.979401    0.979401      0.979401

# %% [markdown]
# ### 3.5.2 <u>The Token Problem</u>
#
# <p style='text-align: justify;'>The token problem and thus the cause of some incorrect predictions of BERTuality can be traced back to the limited vocabulary and the restriction to a single [MASK] token. This vocabulary consists of 30,000 WordPieces. WordPieces make it possible to represent a large number of complicated tokens with a relatively compact vocabulary. A token that is outside the vocabulary is formed by concatenating WordPieces. For example, "kishida" is tokenized by BERT to "ki + ##shi + ##da". To allow related WordPieces to be reassembled into a token, successive WordPieces are marked with a leading "##". The token problem of BERTuality refers to the fact that we are limited to one [MASK] token in our [MASK] sentence and do not know if and from how many WordPieces the searched token is formed. Consequently, the simple input prediction is limited to predicting tokens that consist of a single WordPiece.</p>

# %%
example = "Kishida"

# %%
# the default way of tokenizing
print(example, "get's tokenized into", tokenizer.tokenize(example))
# Out:
# Kishida get's tokenized into ['ki', '##shida']

# %%
# the more powerful tokenizer of bertuality which breaks down tokens into the smallest from of WordPieces
print(example, "get's tokenized into", BERTuality.better_tokenizer(example, tokenizer))
# Out:
# Kishida get's tokenized into ['ki', '##shi', '##da']

# %% [markdown]
# ### 3.5.3 <u>WordPiece-Prediction</u>
#
# <p style='text-align: justify;'>The WordPiece prediction is an extension of the input prediction. This method solves the token problem of many texts and manages to make tokens that are not included in the vocabulary predictable. Tokens, which consist of several connected WordPieces, are called WordPiece-Token (=WPT) in the following for simplification. The WordPiece prediction uses a procedure of concatenated predictions of single WordPieces with the help of a block list. The block list contains modifications of the original input sentence. The modifications of an input sentence are created by inserting the individual WordPieces of the WPT one after the other at the original token position of the WPT of the input sentence. This results in a blocklist with a length n for the number of WordPieces of a WPT. The above mentioned block lists are created for each WPT of a sentence and then passed to BERT for prediction.</p>

# %%
# below you can find an example for a blocklist:

sentence = focus_query[0]

# 1. Step: tokenize the sentence:
tokens = BERTuality.better_tokenizer(sentence, tokenizer)

# 2. Step: find every WordPiece position:
every_wp_position = BERTuality.wp_find_positions(tokens)

# 3. Step: create the blocklist for the sentence
wpw_input_sentences = BERTuality.wp_input_sentence_creator(tokens, every_wp_position, tokenizer)    

print(f'Create blocklist for sentence: "{sentence}"')
print('Found positions of WPT:', every_wp_position)

for nr, i in enumerate(every_wp_position):
    print(f'\nBlock Nr. {nr}')
    for j in i:
        print(f'  WP-Position {j}: {tokens[j]}')
        
print('\nSentences for Block Nr. 0')
for i in wpw_input_sentences[0]:
    print(' ', i)
# Out:
# Create blocklist for sentence: "meet with prime minister fumio kishida the first such summit on japan soil in."
# Found positions of WPT: [[4, 5, 6], [7, 8, 9]]
#
# Block Nr. 0
#   WP-Position 4: fu
#   WP-Position 5: ##mi
#   WP-Position 6: ##o
#
# Block Nr. 1
#   WP-Position 7: ki
#   WP-Position 8: ##shi
#   WP-Position 9: ##da
#
# Sentences for Block Nr. 0
#   meet with prime minister fu the first such summit on japan soil in.
#   meet with prime minister mi the first such summit on japan soil in.
#   meet with prime minister o the first such summit on japan soil in.

# %%
# Now let's move on to the predictions with WordPiece Prediction:

wp_prediction = BERTuality.word_piece_prediction(mask_sentence, focus_query, model, tokenizer, combine=False, threshold=0.8)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 37/37 [01:48<00:00,  2.93s/it]

# %%
wp_prediction_df = wp_prediction[["masked", "input", "token1", "score1"]]
wp_prediction_df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'center')]) ])
# Out:
# <style type="text/css">
# #T_bae83 th {
#   text-align: center;
# }
# #T_bae83_row0_col0, #T_bae83_row0_col1, #T_bae83_row0_col2, #T_bae83_row0_col3, #T_bae83_row1_col0, #T_bae83_row1_col1, #T_bae83_row1_col2, #T_bae83_row1_col3, #T_bae83_row2_col0, #T_bae83_row2_col1, #T_bae83_row2_col2, #T_bae83_row2_col3, #T_bae83_row3_col0, #T_bae83_row3_col1, #T_bae83_row3_col2, #T_bae83_row3_col3, #T_bae83_row4_col0, #T_bae83_row4_col1, #T_bae83_row4_col2, #T_bae83_row4_col3, #T_bae83_row5_col0, #T_bae83_row5_col1, #T_bae83_row5_col2, #T_bae83_row5_col3, #T_bae83_row6_col0, #T_bae83_row6_col1, #T_bae83_row6_col2, #T_bae83_row6_col3, #T_bae83_row7_col0, #T_bae83_row7_col1, #T_bae83_row7_col2, #T_bae83_row7_col3, #T_bae83_row8_col0, #T_bae83_row8_col1, #T_bae83_row8_col2, #T_bae83_row8_col3, #T_bae83_row9_col0, #T_bae83_row9_col1, #T_bae83_row9_col2, #T_bae83_row9_col3, #T_bae83_row10_col0, #T_bae83_row10_col1, #T_bae83_row10_col2, #T_bae83_row10_col3, #T_bae83_row11_col0, #T_bae83_row11_col1, #T_bae83_row11_col2, #T_bae83_row11_col3, #T_bae83_row12_col0, #T_bae83_row12_col1, #T_bae83_row12_col2, #T_bae83_row12_col3, #T_bae83_row13_col0, #T_bae83_row13_col1, #T_bae83_row13_col2, #T_bae83_row13_col3, #T_bae83_row14_col0, #T_bae83_row14_col1, #T_bae83_row14_col2, #T_bae83_row14_col3, #T_bae83_row15_col0, #T_bae83_row15_col1, #T_bae83_row15_col2, #T_bae83_row15_col3, #T_bae83_row16_col0, #T_bae83_row16_col1, #T_bae83_row16_col2, #T_bae83_row16_col3, #T_bae83_row17_col0, #T_bae83_row17_col1, #T_bae83_row17_col2, #T_bae83_row17_col3, #T_bae83_row18_col0, #T_bae83_row18_col1, #T_bae83_row18_col2, #T_bae83_row18_col3, #T_bae83_row19_col0, #T_bae83_row19_col1, #T_bae83_row19_col2, #T_bae83_row19_col3, #T_bae83_row20_col0, #T_bae83_row20_col1, #T_bae83_row20_col2, #T_bae83_row20_col3, #T_bae83_row21_col0, #T_bae83_row21_col1, #T_bae83_row21_col2, #T_bae83_row21_col3, #T_bae83_row22_col0, #T_bae83_row22_col1, #T_bae83_row22_col2, #T_bae83_row22_col3, #T_bae83_row23_col0, #T_bae83_row23_col1, #T_bae83_row23_col2, #T_bae83_row23_col3, #T_bae83_row24_col0, #T_bae83_row24_col1, #T_bae83_row24_col2, #T_bae83_row24_col3, #T_bae83_row25_col0, #T_bae83_row25_col1, #T_bae83_row25_col2, #T_bae83_row25_col3, #T_bae83_row26_col0, #T_bae83_row26_col1, #T_bae83_row26_col2, #T_bae83_row26_col3, #T_bae83_row27_col0, #T_bae83_row27_col1, #T_bae83_row27_col2, #T_bae83_row27_col3, #T_bae83_row28_col0, #T_bae83_row28_col1, #T_bae83_row28_col2, #T_bae83_row28_col3, #T_bae83_row29_col0, #T_bae83_row29_col1, #T_bae83_row29_col2, #T_bae83_row29_col3, #T_bae83_row30_col0, #T_bae83_row30_col1, #T_bae83_row30_col2, #T_bae83_row30_col3, #T_bae83_row31_col0, #T_bae83_row31_col1, #T_bae83_row31_col2, #T_bae83_row31_col3, #T_bae83_row32_col0, #T_bae83_row32_col1, #T_bae83_row32_col2, #T_bae83_row32_col3, #T_bae83_row33_col0, #T_bae83_row33_col1, #T_bae83_row33_col2, #T_bae83_row33_col3, #T_bae83_row34_col0, #T_bae83_row34_col1, #T_bae83_row34_col2, #T_bae83_row34_col3, #T_bae83_row35_col0, #T_bae83_row35_col1, #T_bae83_row35_col2, #T_bae83_row35_col3, #T_bae83_row36_col0, #T_bae83_row36_col1, #T_bae83_row36_col2, #T_bae83_row36_col3, #T_bae83_row37_col0, #T_bae83_row37_col1, #T_bae83_row37_col2, #T_bae83_row37_col3, #T_bae83_row38_col0, #T_bae83_row38_col1, #T_bae83_row38_col2, #T_bae83_row38_col3, #T_bae83_row39_col0, #T_bae83_row39_col1, #T_bae83_row39_col2, #T_bae83_row39_col3, #T_bae83_row40_col0, #T_bae83_row40_col1, #T_bae83_row40_col2, #T_bae83_row40_col3, #T_bae83_row41_col0, #T_bae83_row41_col1, #T_bae83_row41_col2, #T_bae83_row41_col3, #T_bae83_row42_col0, #T_bae83_row42_col1, #T_bae83_row42_col2, #T_bae83_row42_col3, #T_bae83_row43_col0, #T_bae83_row43_col1, #T_bae83_row43_col2, #T_bae83_row43_col3, #T_bae83_row44_col0, #T_bae83_row44_col1, #T_bae83_row44_col2, #T_bae83_row44_col3, #T_bae83_row45_col0, #T_bae83_row45_col1, #T_bae83_row45_col2, #T_bae83_row45_col3, #T_bae83_row46_col0, #T_bae83_row46_col1, #T_bae83_row46_col2, #T_bae83_row46_col3, #T_bae83_row47_col0, #T_bae83_row47_col1, #T_bae83_row47_col2, #T_bae83_row47_col3, #T_bae83 ...
#   text-align: left;
# }
# </style>
# <table id="T_bae83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bae83_level0_col0" class="col_heading level0 col0" >masked</th>
#       <th id="T_bae83_level0_col1" class="col_heading level0 col1" >input</th>
#       <th id="T_bae83_level0_col2" class="col_heading level0 col2" >token1</th>
#       <th id="T_bae83_level0_col3" class="col_heading level0 co

# %%
wp_pred_simple = BERTuality.simple_pred_results(wp_prediction)
wp_pred_simple.head()
# Out:
#      Token  Frequency  max_score  min_score  mean_score  sum_up_score
# 0  kishida         15   0.997021   0.871143    0.981703     14.725542
# 1    fumio         14   0.997911   0.830478    0.979780     13.716922
# 2      who         13   0.815423   0.146832    0.548130      7.125687
# 3       he         11   0.424347   0.162035    0.330206      3.632261
# 4      abe          7   0.484453   0.115956    0.337288      2.361017

# %% [markdown]
# <p style='text-align: justify;'>The WordPiece prediction algorithm allows each WPT to be mapped by individual predictions of the WordPieces. This way, a WordPiece inserted at the original position of the original WPT will still have the same context to the rest of the sentence due to the positional data within the embeddings.</p>

# %%
# let's have a look at our final prediction

print("Predicted [MASK] Token:       ", wp_pred_simple["Token"][0])
print("Final output for our Sentence:", mask_sentence.replace("[MASK]", wp_pred_simple["Token"][0]))
# Out:
# Predicted [MASK] Token:        kishida
# Final output for our Sentence: Prime minister kishida is the leader of Japan.

# %% [markdown]
# # 4. <u>Results & Playground</u>
#
# <p style='text-align: justify;'><b>Result:</b> BERTuality helps correct misinformation in the form of outdated information. Since the use of misinformation is a great danger, the application of BERTuality can be very useful. The obtained performance is a starting point for further development of the method using the presented approaches.</p>
#
# <p style='text-align: justify;'>Below this cell you can test BERTualtiy yourself. You can find an implemented default configuration, but it is also possible to define a custom configuration and play around. </p>

# %%
defaults = BERTuality_quickstart.load_default_config()
values, keys = list(defaults.values()), list(defaults.keys())

pd.DataFrame(values, keys, columns=["Values"])
# Out:
#                                  Values
# model                  bertuality/model
# tokenizer          bertuality/tokenizer
# from_date                    2023-01-25
# to_date                      2023-04-25
# use_NewsAPI                        True
# use_guardian                      False
# use_wikipedia                      True
# subset_size                           2
# sim_score                          0.25
# focus_padding                         6
# duplicates                        False
# extraction                         True
# similarity                         True
# focus                              True
# max_input                            30
# threshold                           0.9
# only_target_token                  True

# %%
# In the default configuration, to_date is always set to today and from_day is set to 90 days in the past.  

BERTuality_quickstart.bertuality("Tim Cook is the current CEO of [MASK].")
# Out:
# Step 1: Load config -------> Done
# Step 2: Load latest data --> Done
# Step 3: Prepare data ------> Done
# Step 4: Start Prediction:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:30<00:00,  1.01s/it]
# Prediction: Tim Cook is the current CEO of Apple.
